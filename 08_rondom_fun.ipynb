# %%
import numpy as np

# %%
print(np.random.rand(5))
# Out:
# [0.62566209 0.32711351 0.6952801  0.69141379 0.49222848]

# %%
print(np.random.randint(1,10,size = 5))
# Out:
# [9 7 3 7 8]

# %%
print(np.random.randn(4))
# Out:
# [-0.15951688 -0.1265609   1.15563599  0.856802  ]

# %%
print(np.random.random(3))
# Out:
# [0.44720383 0.35563455 0.20041151]

# %%
a= np.array([1,2,3,4])
np.random.shuffle(a)
print(a)
# Out:
# [3 1 2 4]

# %%
np.random.seed(20)
print(np.random.randint(1,10,3))
# Out:
# [4 5 7]
